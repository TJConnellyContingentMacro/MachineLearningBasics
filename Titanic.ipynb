# %% [markdown]
# <a href="https://colab.research.google.com/github/GoPackers/NU422/blob/master/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import pandas as pd

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1d37be79-7c47-4d47-b55a-a6e80b0a0dd8" name="files[]" multiple disabled />
#      <output id="result-1d37be79-7c47-4d47-b55a-a6e80b0a0dd8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-ed2fd71b4a2f> in <module>()
# ----> 1 uploaded = files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
#      65   files = _collections.defaultdict(_six.binary_type)
# ...

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "train.csv" with length 61194 bytes

# %%
df = pd.read_csv('train.csv')
df.set_index('PassengerId', inplace=True)
df.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.hist(bins = 50,figsize=(15,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3e7146dba8>,
# ...
#       dtype=object)

# %%
dfCab = df.dropna(subset = ['Cabin'])

# %%
dfCab
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# 22                  1       2
# 24                  1       1
# 28                  0       1
# 32                  1       1
# 53                  1       1
# 55                  0       1
# 56                  1       1
# 62                  1       1
# 63                  0       1
# 67                  1       2
# 76                  0       3
# 89                  1       1
# 93                  0       1
# 97                  0       1
# 98                  1       1
# 103                 0       1
# 111                 0       1
# 119                 0       1
# 124                 1       2
# 125                 0       1
# 129                 1       3
# 137                 1       1
# 138                 0       1
# 140                 0       1
# ...

# %%
dfCab.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  204.000000  204.000000  185.000000  204.000000  204.000000  204.000000
# mean     0.666667    1.196078   35.829297    0.441176    0.436275   76.141504
# std      0.472564    0.525961   15.679356    0.628918    0.729976   74.391749
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.453125
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   55.220850
# 75%      1.000000    1.000000   48.000000    1.000000    1.000000   89.328150
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
Agecut = pd.cut(df['Age'],10)

# %%
Agecut
# Out:
# PassengerId
# 1      (16.336, 24.294]
# 2       (32.252, 40.21]
# 3      (24.294, 32.252]
# 4       (32.252, 40.21]
# 5       (32.252, 40.21]
# 6                   NaN
# 7      (48.168, 56.126]
# 8         (0.34, 8.378]
# 9      (24.294, 32.252]
# 10      (8.378, 16.336]
# 11        (0.34, 8.378]
# 12     (56.126, 64.084]
# 13     (16.336, 24.294]
# 14      (32.252, 40.21]
# 15      (8.378, 16.336]
# 16     (48.168, 56.126]
# 17        (0.34, 8.378]
# 18                  NaN
# 19     (24.294, 32.252]
# 20                  NaN
# 21      (32.252, 40.21]
# 22      (32.252, 40.21]
# 23      (8.378, 16.336]
# 24     (24.294, 32.252]
# 25        (0.34, 8.378]
# 26      (32.252, 40.21]
# 27                  NaN
# 28     (16.336, 24.294]
# 29                  NaN
# 30                  NaN
#              ...
# 862    (16.336, 24.294]
# 863     (40.21, 48.168]
# 864                 NaN
# 865    (16.336, 24.294]
# 866     (40.21, 48.168]
# 867    (24.294, 32.252]
# 868    (24.294, 32.252]
# ...
